# %%
import fukkatsu
print(fukkatsu.__version__)
# Out:
# 2023-07-01 21:56:32,550 - Setting OPENAI_API_KEY
# 2023-07-01 21:56:32,550 - OPENAI_API_KEY found in environment variables.
# 0.0.9

# %%
from fukkatsu import resurrect
from fukkatsu.memory.manage import reset_memory

# %%
import requests

# %%
import time

# %% [markdown]
# ## Error Type -  API Call Type Error
#
# `Scenario`: The function `send_data` is part of a data pipeline. The function is supposed to prepare the data for submission and read the APIs response. However, this time, one of the values is formatted as float but should have been formatted as an integer. This results in a Type error when reading the APIs response.
#
# `Challenge`:
#
# - `send_data` is not able to successfully transmit the `age` variable as a float
# - fukkatsu will have three chances to solve the error
# - if the LLM deems it appropriate, allow installations of completely new libraries by setting the appropriate flag to True
# - the short-term memory is reset after each test
#
# `Accepted Solution`:
#
# - the repaird function should return the list as `b'{"name":"John Doe","age":29,"email":"johndoe@example.com"}'`

# %% [markdown]
# #### Test 1

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 21:56:41,387 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 21:56:41,391 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 21:56:41,392 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 2

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 21:57:47,909 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 21:57:47,909 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 21:57:47,909 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 3

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 21:58:54,336 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 21:58:54,336 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 21:58:54,343 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 4

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:00:01,238 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:00:01,241 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:00:01,241 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 5

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:01:07,684 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:01:07,684 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:01:07,690 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 6

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:02:14,258 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:02:14,258 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:02:14,264 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 7

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:03:22,357 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:03:22,363 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:03:22,364 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 8

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:04:30,399 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:04:30,401 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:04:30,402 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 9

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:05:36,683 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:05:36,683 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:05:36,690 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 10

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:06:44,251 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:06:44,253 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:06:44,254 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 11

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:07:51,752 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:07:51,752 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:07:51,758 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 12

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:08:58,692 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:08:58,692 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:08:58,699 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 13

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:10:05,240 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:10:05,240 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:10:05,247 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 14

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:11:12,204 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:11:12,206 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:11:12,207 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 15

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:12:19,867 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:12:19,867 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:12:19,873 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 16

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:13:27,435 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:13:27,435 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:13:27,435 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 17

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:14:34,436 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:14:34,436 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:14:34,442 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 18

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:15:41,775 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:15:41,775 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:15:41,783 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 19

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:16:48,790 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:16:48,790 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:16:48,796 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 20

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:17:55,385 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:17:55,388 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:17:55,389 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 21

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:19:02,753 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:19:02,756 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:19:02,756 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 22

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:20:10,486 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:20:10,489 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:20:10,490 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 23

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:21:17,525 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:21:17,525 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:21:17,532 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 24

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:22:24,852 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:22:24,852 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:22:24,858 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 25

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:23:31,624 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:23:31,624 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:23:31,630 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 26

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:24:37,851 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:24:37,851 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:24:37,858 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 27

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:25:44,701 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:25:44,701 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:25:44,708 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 28

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:26:51,587 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:26:51,590 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:26:51,591 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 29

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:27:57,958 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:27:57,958 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:27:57,964 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 30

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:29:05,827 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:29:05,827 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:29:05,834 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 31

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:30:13,336 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:30:13,336 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:30:13,336 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 32

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:31:20,593 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:31:20,593 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:31:20,599 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 33

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:32:27,605 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:32:27,607 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:32:27,608 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 34

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:33:34,324 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:33:34,324 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:33:34,331 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 35

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:34:41,038 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:34:41,038 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:34:41,044 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 36

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:35:47,459 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:35:47,459 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:35:47,459 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 37

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:36:53,975 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:36:53,975 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:36:53,982 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 38

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:38:00,256 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:38:00,258 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:38:00,259 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 39

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:39:06,975 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:39:06,975 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:39:06,983 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 40

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:40:13,415 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:40:13,415 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:40:13,415 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 41

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:41:19,854 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:41:19,854 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:41:19,860 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 42

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:42:26,124 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:42:26,124 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:42:26,130 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 43

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:43:34,557 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:43:34,557 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:43:34,557 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 44

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:44:41,024 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:44:41,024 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:44:41,031 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 45

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:45:47,453 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:45:47,453 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:45:47,459 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 46

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:46:54,041 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:46:54,041 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:46:54,047 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 47

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:48:00,525 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:48:00,525 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:48:00,531 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 48

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:49:06,706 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:49:06,706 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:49:06,714 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 49

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:50:13,649 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:50:13,649 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:50:13,655 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %%
time.sleep(60)

# %% [markdown]
# #### Test 50

# %%
data = {
    "name": "John Doe",
    "age": "50",
    "email": "johndoe@example.com"
}

reset_memory()
@resurrect(lives=3, allow_installs = True)
def send_data(name: str, age: int, email: str):
    
    data = {"name": name,
            "age": age,
            "email": email
           }
    
    
    
    response = requests.post("http://localhost:8000/endpoint", json=data)
    response_data = response.json()

    if response.status_code == 200:
        return response.content
    else:
        error_message = response_data.get("detail")
        raise Exception(error_message)
        
send_data(name = "John Doe", age = 29.0, email = "johndoe@example.com")
# Out:
# 2023-07-01 22:51:20,756 - [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_16528\1775903200.py", line 25, in send_data
#     raise Exception(error_message)
# Exception: [{'loc': ['body', 'age'], 'msg': 'value is not a valid integer', 'type': 'type_error.integer'}]
# 2023-07-01 22:51:20,756 - Input arguments: {'name': 'John Doe', 'age': 29.0, 'email': 'johndoe@example.com'}
#
# 2023-07-01 22:51:20,763 -
# Source Code:
#  def send_data(name: str, age: int, email: str):
#
#     data = {"name": name,
#             "age": age,
#             "email": email
#            }
#
#
#
#     response = requests.post("http://localhost:8000/endpoint", json=data)
#     response_data = response.json()
#
# ...

# %% [markdown]
# ## Result

# %%
import scipy.stats as stats

successes = 50

alpha = 0.05

p_value = stats.binom_test(successes, n=50, p=0.5, alternative='greater')

print(f"p_value: {p_value}")

if p_value < alpha:
    print("Reject the null hypothesis")
    print("The proportion of errors solved is significantly greater than 0.5.")
else:
    print("Fail to reject the null hypothesis")
    print("The proportion of errors solved is not significantly greater than 0.5.")
# Out:
# p_value: 8.881784197001252e-16
# Reject the null hypothesis
# The proportion of errors solved is significantly greater than 0.5.
