# %%
import fukkatsu
print(fukkatsu.__version__)
# Out:
# 2023-06-29 23:31:33,792 - Setting OPENAI_API_KEY
# 2023-06-29 23:31:33,797 - OPENAI_API_KEY found in environment variables.
# 0.0.9

# %%
from fukkatsu import resurrect
from fukkatsu.memory.manage import reset_memory

# %%
from typing import List

# %%
from datetime import datetime
import time

# %% [markdown]
# ## Error Type - Value Error
#
# `Scenario`: The function `date_transformation` is part of a data pipeline. The function is supposed to take in a list of dates in string format and cast them into datetime format. However, this time, some of the string dates do not follow the expected string format: `%Y-%m-%d`. The function receives the following list: `["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]`
#
# `Challenge`:
#
# - `date_transformation` is not able to cast `1 June 2020`, `2023.07.07`, `2020/01/01` and `Nov 11 1994` into datetime objects
# - fukkatsu will have three chances to solve the error
# - the `additional_req` argument is used to provide more context on the purpose of the function:
#     - `"Transform each element in the list. Account for multiple dateformats if necessary."`
# - if the LLM deems it appropriate, allow installations of completely new libraries by setting the appropriate flag to True
# - the short-term memory is reset after each test
#
# `Accepted Solution`:
#
# - the repaird function should return the list as:
#
# ```
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]
#  ```

# %% [markdown]
# #### Test 1

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-29 23:32:24,784 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-29 23:32:24,805 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-29 23:32:24,813 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-29 23:32:24,813 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-29 23:32:24,815 - API REQUEST to gpt-3.5-turbo
# 2023-06-29 23:32:28,931 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
# |||
#
# 2023-06-29 23:32:28,931 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
#
# 2023-06-29 23:32:28,931 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
#
# 2023-06-29 23:32:28,931 - Attempt 1 to reanimate
#
# 2023-06-29 23:32:28,939 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 2

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-29 23:33:28,993 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-29 23:33:28,997 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-29 23:33:28,998 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-29 23:33:29,000 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-29 23:33:29,000 - API REQUEST to gpt-3.5-turbo
# 2023-06-29 23:33:32,869 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# |||
#
# 2023-06-29 23:33:32,869 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-29 23:33:32,886 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-29 23:33:32,886 - Attempt 1 to reanimate
#
# 2023-06-29 23:33:32,892 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 3

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-29 23:34:32,972 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-29 23:34:32,979 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-29 23:34:32,979 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-29 23:34:32,979 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-29 23:34:32,979 - API REQUEST to gpt-3.5-turbo
# 2023-06-29 23:34:37,614 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# |||
#
# 2023-06-29 23:34:37,614 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-29 23:34:37,614 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-29 23:34:37,614 - Attempt 1 to reanimate
#
# 2023-06-29 23:34:37,622 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 4

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-29 23:35:37,671 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-29 23:35:37,678 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-29 23:35:37,678 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-29 23:35:37,678 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-29 23:35:37,683 - API REQUEST to gpt-3.5-turbo
# 2023-06-29 23:35:42,204 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
# |||
#
# 2023-06-29 23:35:42,204 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
#
# 2023-06-29 23:35:42,204 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
#
# 2023-06-29 23:35:42,219 - Attempt 1 to reanimate
#
# 2023-06-29 23:35:42,219 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 5

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-29 23:36:42,299 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-29 23:36:42,305 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-29 23:36:42,305 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-29 23:36:42,305 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-29 23:36:42,305 - API REQUEST to gpt-3.5-turbo
# 2023-06-29 23:36:46,942 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
# |||
#
# 2023-06-29 23:36:46,942 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
#
# 2023-06-29 23:36:46,942 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
#
# 2023-06-29 23:36:46,951 - Attempt 1 to reanimate
#
# 2023-06-29 23:36:46,951 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 6

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-29 23:37:47,016 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-29 23:37:47,024 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-29 23:37:47,025 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-29 23:37:47,025 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-29 23:37:47,025 - API REQUEST to gpt-3.5-turbo
# 2023-06-29 23:37:54,649 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# |||
#
# 2023-06-29 23:37:54,649 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-29 23:37:54,649 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-29 23:37:54,649 - Attempt 1 to reanimate
#
# 2023-06-29 23:37:54,658 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 7

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-29 23:38:54,698 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-29 23:38:54,704 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-29 23:38:54,705 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-29 23:38:54,706 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-29 23:38:54,707 - API REQUEST to gpt-3.5-turbo
# 2023-06-29 23:38:58,520 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
# |||
#
# 2023-06-29 23:38:58,520 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
#
# 2023-06-29 23:38:58,536 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
#
# 2023-06-29 23:38:58,541 - Attempt 1 to reanimate
#
# 2023-06-29 23:38:58,541 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 8

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-29 23:39:58,600 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-29 23:39:58,606 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-29 23:39:58,608 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-29 23:39:58,608 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-29 23:39:58,608 - API REQUEST to gpt-3.5-turbo
# 2023-06-29 23:40:03,531 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
# |||
#
# 2023-06-29 23:40:03,531 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
#
# 2023-06-29 23:40:03,549 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
#
# 2023-06-29 23:40:03,549 - Attempt 1 to reanimate
#
# 2023-06-29 23:40:03,549 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 9

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-29 23:41:03,608 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-29 23:41:03,613 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-29 23:41:03,614 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-29 23:41:03,614 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-29 23:41:03,614 - API REQUEST to gpt-3.5-turbo
# 2023-06-29 23:41:08,143 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# |||
#
# 2023-06-29 23:41:08,143 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-29 23:41:08,143 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-29 23:41:08,157 - Attempt 1 to reanimate
#
# 2023-06-29 23:41:08,157 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 10

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-29 23:42:08,233 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-29 23:42:08,238 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-29 23:42:08,238 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-29 23:42:08,238 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-29 23:42:08,238 - API REQUEST to gpt-3.5-turbo
# 2023-06-29 23:42:12,147 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# |||
#
# 2023-06-29 23:42:12,147 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-29 23:42:12,164 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-29 23:42:12,164 - Attempt 1 to reanimate
#
# 2023-06-29 23:42:12,164 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 11

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-29 23:43:12,235 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-29 23:43:12,240 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-29 23:43:12,241 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-29 23:43:12,242 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-29 23:43:12,242 - API REQUEST to gpt-3.5-turbo
# 2023-06-29 23:43:16,104 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# |||
#
# 2023-06-29 23:43:16,104 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-29 23:43:16,117 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-29 23:43:16,117 - Attempt 1 to reanimate
#
# 2023-06-29 23:43:16,125 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 12

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-29 23:44:16,174 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-29 23:44:16,181 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-29 23:44:16,182 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-29 23:44:16,183 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-29 23:44:16,185 - API REQUEST to gpt-3.5-turbo
# 2023-06-29 23:46:17,745 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# |||
#
# 2023-06-29 23:46:17,760 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-29 23:46:17,762 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-29 23:46:17,765 - Attempt 1 to reanimate
#
# 2023-06-29 23:46:17,770 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 13

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-29 23:47:17,826 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-29 23:47:17,830 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-29 23:47:17,831 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-29 23:47:17,833 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-29 23:47:17,836 - API REQUEST to gpt-3.5-turbo
# 2023-06-29 23:47:21,640 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# |||
#
# 2023-06-29 23:47:21,640 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-29 23:47:21,640 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-29 23:47:21,640 - Attempt 1 to reanimate
#
# 2023-06-29 23:47:21,651 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 14

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-29 23:48:21,715 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-29 23:48:21,718 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-29 23:48:21,718 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-29 23:48:21,718 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-29 23:48:21,718 - API REQUEST to gpt-3.5-turbo
# 2023-06-29 23:48:26,064 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# |||
#
# 2023-06-29 23:48:26,064 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-29 23:48:26,064 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-29 23:48:26,068 - Attempt 1 to reanimate
#
# 2023-06-29 23:48:26,069 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 15

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-29 23:49:26,131 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-29 23:49:26,135 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-29 23:49:26,137 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-29 23:49:26,138 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-29 23:49:26,140 - API REQUEST to gpt-3.5-turbo
# 2023-06-29 23:49:30,757 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
# |||
#
# 2023-06-29 23:49:30,757 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
#
# 2023-06-29 23:49:30,772 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
#
# 2023-06-29 23:49:30,773 - Attempt 1 to reanimate
#
# 2023-06-29 23:49:30,776 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 16

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-29 23:50:30,827 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-29 23:50:30,830 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-29 23:50:30,831 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-29 23:50:30,832 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-29 23:50:30,833 - API REQUEST to gpt-3.5-turbo
# 2023-06-29 23:50:35,228 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# |||
#
# 2023-06-29 23:50:35,228 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-29 23:50:35,228 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-29 23:50:35,240 - Attempt 1 to reanimate
#
# 2023-06-29 23:50:35,241 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 17

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-29 23:51:35,293 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-29 23:51:35,296 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-29 23:51:35,297 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-29 23:51:35,298 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-29 23:51:35,299 - API REQUEST to gpt-3.5-turbo
# 2023-06-29 23:51:39,356 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# |||
#
# 2023-06-29 23:51:39,356 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-29 23:51:39,356 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-29 23:51:39,361 - Attempt 1 to reanimate
#
# 2023-06-29 23:51:39,362 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 18

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-29 23:52:39,404 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-29 23:52:39,411 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-29 23:52:39,413 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-29 23:52:39,414 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-29 23:52:39,415 - API REQUEST to gpt-3.5-turbo
# 2023-06-29 23:52:43,488 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
# |||
#
# 2023-06-29 23:52:43,488 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
#
# 2023-06-29 23:52:43,488 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
#
# 2023-06-29 23:52:43,496 - Attempt 1 to reanimate
#
# 2023-06-29 23:52:43,497 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 19

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-29 23:53:43,539 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-29 23:53:43,544 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-29 23:53:43,544 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-29 23:53:43,545 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-29 23:53:43,546 - API REQUEST to gpt-3.5-turbo
# 2023-06-29 23:53:48,206 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# |||
#
# 2023-06-29 23:53:48,220 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-29 23:53:48,222 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-29 23:53:48,223 - Attempt 1 to reanimate
#
# 2023-06-29 23:53:48,225 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 20

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-29 23:54:48,276 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-29 23:54:48,280 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-29 23:54:48,280 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-29 23:54:48,281 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-29 23:54:48,282 - API REQUEST to gpt-3.5-turbo
# 2023-06-29 23:54:52,633 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
# |||
#
# 2023-06-29 23:54:52,633 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
#
# 2023-06-29 23:54:52,633 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
#
# 2023-06-29 23:54:52,638 - Attempt 1 to reanimate
#
# 2023-06-29 23:54:52,639 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 21

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-29 23:55:52,690 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-29 23:55:52,695 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-29 23:55:52,696 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-29 23:55:52,697 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-29 23:55:52,699 - API REQUEST to gpt-3.5-turbo
# 2023-06-29 23:55:56,941 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# |||
#
# 2023-06-29 23:55:56,941 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-29 23:55:56,941 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-29 23:55:56,950 - Attempt 1 to reanimate
#
# 2023-06-29 23:55:56,951 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 22

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-29 23:56:56,994 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-29 23:56:56,999 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-29 23:56:57,000 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-29 23:56:57,000 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-29 23:56:57,001 - API REQUEST to gpt-3.5-turbo
# 2023-06-29 23:57:01,046 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# |||
#
# 2023-06-29 23:57:01,046 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-29 23:57:01,046 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-29 23:57:01,057 - Attempt 1 to reanimate
#
# 2023-06-29 23:57:01,058 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 23

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-29 23:58:01,109 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-29 23:58:01,112 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-29 23:58:01,113 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-29 23:58:01,113 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-29 23:58:01,115 - API REQUEST to gpt-3.5-turbo
# 2023-06-29 23:58:04,823 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# |||
#
# 2023-06-29 23:58:04,823 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-29 23:58:04,823 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-29 23:58:04,828 - Attempt 1 to reanimate
#
# 2023-06-29 23:58:04,829 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 24

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-29 23:59:04,880 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-29 23:59:04,883 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-29 23:59:04,885 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-29 23:59:04,886 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-29 23:59:04,886 - API REQUEST to gpt-3.5-turbo
# 2023-06-29 23:59:08,563 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# |||
#
# 2023-06-29 23:59:08,564 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-29 23:59:08,565 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-29 23:59:08,566 - Attempt 1 to reanimate
#
# 2023-06-29 23:59:08,567 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 25

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-30 00:00:08,616 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-30 00:00:08,620 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-30 00:00:08,621 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-30 00:00:08,622 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-30 00:00:08,624 - API REQUEST to gpt-3.5-turbo
# 2023-06-30 00:00:13,241 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# |||
#
# 2023-06-30 00:00:13,241 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:00:13,241 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:00:13,241 - Attempt 1 to reanimate
#
# 2023-06-30 00:00:13,258 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 26

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-30 00:01:13,305 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-30 00:01:13,308 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-30 00:01:13,309 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-30 00:01:13,310 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-30 00:01:13,311 - API REQUEST to gpt-3.5-turbo
# 2023-06-30 00:01:17,593 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# |||
#
# 2023-06-30 00:01:17,593 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:01:17,608 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:01:17,609 - Attempt 1 to reanimate
#
# 2023-06-30 00:01:17,611 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 27

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-30 00:02:17,656 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-30 00:02:17,660 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-30 00:02:17,661 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-30 00:02:17,662 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-30 00:02:17,662 - API REQUEST to gpt-3.5-turbo
# 2023-06-30 00:02:21,541 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# |||
#
# 2023-06-30 00:02:21,556 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:02:21,557 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:02:21,557 - Attempt 1 to reanimate
#
# 2023-06-30 00:02:21,559 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 28

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-30 00:03:21,609 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-30 00:03:21,613 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-30 00:03:21,613 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-30 00:03:21,613 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-30 00:03:21,613 - API REQUEST to gpt-3.5-turbo
# 2023-06-30 00:03:25,238 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data:List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# |||
#
# 2023-06-30 00:03:25,238 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data:List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:03:25,238 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data:List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:03:25,249 - Attempt 1 to reanimate
#
# 2023-06-30 00:03:25,250 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data:List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 29

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-30 00:04:25,293 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-30 00:04:25,297 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-30 00:04:25,298 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-30 00:04:25,298 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-30 00:04:25,299 - API REQUEST to gpt-3.5-turbo
# 2023-06-30 00:04:29,528 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
# |||
#
# 2023-06-30 00:04:29,528 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
#
# 2023-06-30 00:04:29,528 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
#
# 2023-06-30 00:04:29,528 - Attempt 1 to reanimate
#
# 2023-06-30 00:04:29,538 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 30

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-30 00:05:29,600 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-30 00:05:29,604 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-30 00:05:29,604 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-30 00:05:29,605 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-30 00:05:29,606 - API REQUEST to gpt-3.5-turbo
# 2023-06-30 00:05:33,651 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# |||
#
# 2023-06-30 00:05:33,651 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:05:33,651 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:05:33,651 - Attempt 1 to reanimate
#
# 2023-06-30 00:05:33,665 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 31

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-30 00:06:33,706 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-30 00:06:33,710 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-30 00:06:33,710 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-30 00:06:33,710 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-30 00:06:33,710 - API REQUEST to gpt-3.5-turbo
# 2023-06-30 00:06:39,018 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# |||
#
# 2023-06-30 00:06:39,019 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:06:39,019 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:06:39,023 - Attempt 1 to reanimate
#
# 2023-06-30 00:06:39,024 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 32

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-30 00:07:39,071 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-30 00:07:39,073 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-30 00:07:39,073 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-30 00:07:39,073 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-30 00:07:39,073 - API REQUEST to gpt-3.5-turbo
# 2023-06-30 00:07:42,727 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# |||
#
# 2023-06-30 00:07:42,741 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:07:42,742 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:07:42,742 - Attempt 1 to reanimate
#
# 2023-06-30 00:07:42,745 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 33

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-30 00:08:42,786 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-30 00:08:42,791 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-30 00:08:42,791 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-30 00:08:42,792 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-30 00:08:42,794 - API REQUEST to gpt-3.5-turbo
# 2023-06-30 00:08:46,390 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
# |||
#
# 2023-06-30 00:08:46,390 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
#
# 2023-06-30 00:08:46,390 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
#
# 2023-06-30 00:08:46,390 - Attempt 1 to reanimate
#
# 2023-06-30 00:08:46,397 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 34

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-30 00:09:46,437 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-30 00:09:46,437 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-30 00:09:46,437 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-30 00:09:46,437 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-30 00:09:46,437 - API REQUEST to gpt-3.5-turbo
# 2023-06-30 00:09:50,053 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
# |||
#
# 2023-06-30 00:09:50,053 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
#
# 2023-06-30 00:09:50,068 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
#
# 2023-06-30 00:09:50,069 - Attempt 1 to reanimate
#
# 2023-06-30 00:09:50,071 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 35

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-30 00:10:50,119 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-30 00:10:50,122 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-30 00:10:50,124 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-30 00:10:50,124 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-30 00:10:50,126 - API REQUEST to gpt-3.5-turbo
# 2023-06-30 00:10:53,696 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
# |||
#
# 2023-06-30 00:10:53,696 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
#
# 2023-06-30 00:10:53,696 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
#
# 2023-06-30 00:10:53,696 - Attempt 1 to reanimate
#
# 2023-06-30 00:10:53,705 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 36

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-30 00:11:53,739 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-30 00:11:53,742 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-30 00:11:53,743 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-30 00:11:53,744 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-30 00:11:53,744 - API REQUEST to gpt-3.5-turbo
# 2023-06-30 00:11:58,146 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# |||
#
# 2023-06-30 00:11:58,146 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:11:58,146 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:11:58,146 - Attempt 1 to reanimate
#
# 2023-06-30 00:11:58,156 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 37

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-30 00:12:58,190 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-30 00:12:58,190 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-30 00:12:58,190 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-30 00:12:58,190 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-30 00:12:58,190 - API REQUEST to gpt-3.5-turbo
# 2023-06-30 00:13:01,991 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# |||
#
# 2023-06-30 00:13:01,991 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:13:01,991 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:13:01,991 - Attempt 1 to reanimate
#
# 2023-06-30 00:13:01,991 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 38

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-30 00:14:02,047 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-30 00:14:02,050 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-30 00:14:02,051 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-30 00:14:02,051 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-30 00:14:02,053 - API REQUEST to gpt-3.5-turbo
# 2023-06-30 00:14:05,881 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
# |||
#
# 2023-06-30 00:14:05,882 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
#
# 2023-06-30 00:14:05,883 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
#
# 2023-06-30 00:14:05,884 - Attempt 1 to reanimate
#
# 2023-06-30 00:14:05,885 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 39

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-30 00:15:05,935 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-30 00:15:05,939 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-30 00:15:05,940 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-30 00:15:05,941 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-30 00:15:05,942 - API REQUEST to gpt-3.5-turbo
# 2023-06-30 00:15:09,823 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# |||
#
# 2023-06-30 00:15:09,823 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:15:09,823 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:15:09,823 - Attempt 1 to reanimate
#
# 2023-06-30 00:15:09,839 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 40

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-30 00:16:09,862 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-30 00:16:09,862 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-30 00:16:09,862 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-30 00:16:09,862 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-30 00:16:09,877 - API REQUEST to gpt-3.5-turbo
# 2023-06-30 00:16:13,733 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# |||
#
# 2023-06-30 00:16:13,734 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:16:13,735 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:16:13,736 - Attempt 1 to reanimate
#
# 2023-06-30 00:16:13,737 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 41

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-30 00:17:13,780 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-30 00:17:13,782 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-30 00:17:13,783 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-30 00:17:13,784 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-30 00:17:13,785 - API REQUEST to gpt-3.5-turbo
# 2023-06-30 00:17:17,640 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# |||
#
# 2023-06-30 00:17:17,641 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:17:17,641 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:17:17,644 - Attempt 1 to reanimate
#
# 2023-06-30 00:17:17,645 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 42

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-30 00:18:17,712 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-30 00:18:17,721 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-30 00:18:17,722 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-30 00:18:17,722 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-30 00:18:17,723 - API REQUEST to gpt-3.5-turbo
# 2023-06-30 00:18:21,408 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# |||
#
# 2023-06-30 00:18:21,409 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:18:21,410 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:18:21,410 - Attempt 1 to reanimate
#
# 2023-06-30 00:18:21,410 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 43

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-30 00:19:21,453 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-30 00:19:21,456 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-30 00:19:21,457 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-30 00:19:21,458 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-30 00:19:21,459 - API REQUEST to gpt-3.5-turbo
# 2023-06-30 00:19:25,140 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# |||
#
# 2023-06-30 00:19:25,140 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:19:25,140 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:19:25,150 - Attempt 1 to reanimate
#
# 2023-06-30 00:19:25,151 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 44

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-30 00:20:25,197 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-30 00:20:25,200 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-30 00:20:25,202 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-30 00:20:25,203 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-30 00:20:25,203 - API REQUEST to gpt-3.5-turbo
# 2023-06-30 00:20:29,083 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# |||
#
# 2023-06-30 00:20:29,083 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:20:29,083 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:20:29,083 - Attempt 1 to reanimate
#
# 2023-06-30 00:20:29,090 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 45

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-30 00:21:29,130 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-30 00:21:29,134 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-30 00:21:29,135 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-30 00:21:29,136 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-30 00:21:29,137 - API REQUEST to gpt-3.5-turbo
# 2023-06-30 00:21:32,869 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
# |||
#
# 2023-06-30 00:21:32,869 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
#
# 2023-06-30 00:21:32,869 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
#
# 2023-06-30 00:21:32,886 - Attempt 1 to reanimate
#
# 2023-06-30 00:21:32,888 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 46

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-30 00:22:32,935 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-30 00:22:32,938 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-30 00:22:32,940 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-30 00:22:32,941 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-30 00:22:32,942 - API REQUEST to gpt-3.5-turbo
# 2023-06-30 00:22:36,577 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# |||
#
# 2023-06-30 00:22:36,577 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:22:36,577 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:22:36,577 - Attempt 1 to reanimate
#
# 2023-06-30 00:22:36,582 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 47

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-30 00:23:36,619 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-30 00:23:36,623 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-30 00:23:36,624 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-30 00:23:36,625 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-30 00:23:36,626 - API REQUEST to gpt-3.5-turbo
# 2023-06-30 00:23:40,272 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# |||
#
# 2023-06-30 00:23:40,272 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:23:40,272 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:23:40,272 - Attempt 1 to reanimate
#
# 2023-06-30 00:23:40,287 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 48

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-30 00:24:40,335 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-30 00:24:40,338 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-30 00:24:40,339 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-30 00:24:40,339 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-30 00:24:40,339 - API REQUEST to gpt-3.5-turbo
# 2023-06-30 00:24:44,568 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# |||
#
# 2023-06-30 00:24:44,568 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:24:44,568 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:24:44,568 - Attempt 1 to reanimate
#
# 2023-06-30 00:24:44,577 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 49

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-30 00:25:44,618 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-30 00:25:44,623 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-30 00:25:44,623 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-30 00:25:44,624 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-30 00:25:44,625 - API REQUEST to gpt-3.5-turbo
# 2023-06-30 00:25:49,391 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
# |||
#
# 2023-06-30 00:25:49,391 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
#
# 2023-06-30 00:25:49,392 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
#
# 2023-06-30 00:25:49,393 - Attempt 1 to reanimate
#
# 2023-06-30 00:25:49,395 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 pass
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %%
time.sleep(60)

# %% [markdown]
# #### Test 50

# %%
data = ["2023-07-07", "1 June 2020", "2023.07.07", "2023-12-01", "2020/01/01", "Nov 11 1994"]

reset_memory()
@resurrect(lives=3, allow_installs = True, additional_req = "Transform each element in the list. Account for multiple dateformats if necessary.")
def date_transformation(data:List[str]) -> List[datetime]:
    """Takes in a list of dates in string format and transforms each element in datetime objects.
    """
    date_format = '%Y-%m-%d'
    
    for idx, date in enumerate(data):
        data[idx] = datetime.strptime(date, date_format)
        
    return data

date_transformation(data)
# Out:
# 2023-06-30 00:26:49,446 - time data '1 June 2020' does not match format '%Y-%m-%d'
# Traceback (most recent call last):
#   File "c:\users\max\documents\research\fukkatsu\fukkatsu\fukkatsu\__init__.py", line 37, in wrapper
#     result = func(*args_copy, **kwargs_copy)
#   File "C:\Users\Max\AppData\Local\Temp\ipykernel_6104\3505730919.py", line 11, in date_transformation
#     data[idx] = datetime.strptime(date, date_format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "C:\Users\Max\anaconda3\lib\_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1 June 2020' does not match format '%Y-%m-%d'
# 2023-06-30 00:26:49,451 - Input arguments: {'data': ['2023-07-07', '1 June 2020', '2023.07.07', '2023-12-01', '2020/01/01', 'Nov 11 1994']}
#
# 2023-06-30 00:26:49,452 -
# Source Code:
#  def date_transformation(data:List[str]) -> List[datetime]:
#     """Takes in a list of dates in string format and transforms each element in datetime objects.
#     """
#     date_format = '%Y-%m-%d'
#
#     for idx, date in enumerate(data):
#         data[idx] = datetime.strptime(date, date_format)
#
#     return data
#
#
# 2023-06-30 00:26:49,452 - Requesting INITIAL correction - Attempt 1
#
# 2023-06-30 00:26:49,454 - API REQUEST to gpt-3.5-turbo
# 2023-06-30 00:26:53,039 - Received INITIAL RAW suggestion:
# |||from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# |||
#
# 2023-06-30 00:26:53,039 - Received INITIAL CLEANED suggestion:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:26:53,039 - Import block added to suggested code:
#  from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
#
# 2023-06-30 00:26:53,039 - Attempt 1 to reanimate
#
# 2023-06-30 00:26:53,044 - Reanimation successful, using:
# from typing import List
# from datetime import datetime
#
# def date_transformation(data: List[str]) -> List[datetime]:
#     from typing import List
#     from datetime import datetime
#     date_formats = ['%Y-%m-%d', '%d %B %Y', '%Y.%m.%d', '%Y/%m/%d', '%b %d %Y']
#     transformed_dates = []
#
#     for date in data:
#         for date_format in date_formats:
#             try:
#                 transformed_date = datetime.strptime(date, date_format)
#                 transformed_dates.append(transformed_date)
#                 break
#             except ValueError:
#                 continue
#
#     return transformed_dates
# [datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2020, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 7, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(1994, 11, 11, 0, 0)]

# %% [markdown]
# ## Result

# %%
import scipy.stats as stats

successes = 50

alpha = 0.05

p_value = stats.binom_test(successes, n=50, p=0.5, alternative='greater')

print(f"p_value: {p_value}")

if p_value < alpha:
    print("Reject the null hypothesis")
    print("The proportion of errors solved is significantly greater than 0.5.")
else:
    print("Fail to reject the null hypothesis")
    print("The proportion of errors solved is not significantly greater than 0.5.")
# Out:
# p_value: 8.881784197001252e-16
# Reject the null hypothesis
# The proportion of errors solved is significantly greater than 0.5.
